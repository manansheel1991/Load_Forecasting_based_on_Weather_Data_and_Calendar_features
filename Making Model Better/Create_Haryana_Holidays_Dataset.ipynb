# %%
import pandas as pd

# %%
countries_holidays = pd.read_csv('holiday_dates.csv')

# %%
countries_holidays
# Out:
#         Unnamed: 0 country_code   country_name country_holiday_dates  \
# 0                0           US  United States            1950-01-01
# 1                1           US  United States            1950-01-02
# 2                2           US  United States            1950-02-22
# 3                3           US  United States            1950-07-04
# 4                4           US  United States            1950-09-04
# ...            ...          ...            ...                   ...
# 178783      178783           GP     Guadeloupe            2049-07-14
# 178784      178784           GP     Guadeloupe            2049-08-15
# 178785      178785           GP     Guadeloupe            2049-11-01
# 178786      178786           GP     Guadeloupe            2049-11-11
# 178787      178787           GP     Guadeloupe            2049-12-25
#
#                   country_holiday
# 0                  New Year's Day
# 1       'New Year's Day' observed
# ...

# %%
india_holidays = countries_holidays[countries_holidays['country_name'] == 'India']

# %%
india_holidays
# Out:
#        Unnamed: 0 country_code country_name country_holiday_dates  \
# 32082       32082           IN        India            2005-01-26
# 32083       32083           IN        India            2005-03-08
# 32084       32084           IN        India            2005-03-25
# 32085       32085           IN        India            2005-04-17
# 32086       32086           IN        India            2005-04-22
# ...           ...          ...          ...                   ...
# 32351       32351           IN        India            2021-10-02
# 32352       32352           IN        India            2021-10-15
# 32353       32353           IN        India            2021-11-04
# 32354       32354           IN        India            2021-11-19
# 32355       32355           IN        India            2021-12-25
#
#                   country_holiday
# 32082                Republic Day
# 32083  Maha Shivaratri/Shivaratri
# 32084                 Good Friday
# ...

# %%
india_holidays = india_holidays[['country_holiday_dates', 'country_holiday']]

# %%
india_holidays.reset_index(inplace=True)

# %%
india_holidays.drop(columns = 'index', inplace=True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
india_holidays
# Out:
#     country_holiday_dates             country_holiday
# 0              2005-01-26                Republic Day
# 1              2005-03-08  Maha Shivaratri/Shivaratri
# 2              2005-03-25                 Good Friday
# 3              2005-04-17                 Rama Navami
# 4              2005-04-22             Mahavir Jayanti
# ..                    ...                         ...
# 269            2021-10-02      Mahatma Gandhi Jayanti
# 270            2021-10-15                    Dussehra
# 271            2021-11-04            Diwali/Deepavali
# 272            2021-11-19          Guru Nanak Jayanti
# 273            2021-12-25                   Christmas
#
# [274 rows x 2 columns]

# %%
india_holidays[india_holidays['country_holiday_dates'] == '2016-01-26']
# Out:
#     country_holiday_dates country_holiday
# 168            2016-01-26    Republic Day

# %%
india_holidays = india_holidays[168:]

# %%
india_holidays.reset_index(inplace=True)

# %%
india_holidays.drop(columns='index', inplace=True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
india_holidays
# Out:
#     country_holiday_dates             country_holiday
# 0              2016-01-26                Republic Day
# 1              2016-03-07  Maha Shivaratri/Shivaratri
# 2              2016-03-25                 Good Friday
# 3              2016-04-15                 Rama Navami
# 4              2016-04-20             Mahavir Jayanti
# ..                    ...                         ...
# 101            2021-10-02      Mahatma Gandhi Jayanti
# 102            2021-10-15                    Dussehra
# 103            2021-11-04            Diwali/Deepavali
# 104            2021-11-19          Guru Nanak Jayanti
# 105            2021-12-25                   Christmas
#
# [106 rows x 2 columns]

# %%
india_holidays.to_csv('India_Holidays.csv')
